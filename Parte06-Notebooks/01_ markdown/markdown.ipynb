# %% [markdown]
# # Titulo do meu documento
#
# Nesta aula iremos aprender sobre como inserir ***markdwns*** dentro de arquivos do tipo **Jupyter Notebook**.
#
# > ***Markdown*** é um tipo de documento muito usado em ciência de dados e tambem para alimentar Inteligência Artificial.
#
# Manipular este tipo de arquivo se torna fundamental para dominar as profissões do futuro que dependem de IAs.

# %% [markdown]
# ## Subtitulo de markdown
#
# O que diferencia um markdown de um notebook, é que no caso do notebook, ele também é capaz de ler código das linguagens de programação *R*, *Julia*, e é claro, *Python*.

# %% [markdown]
# ## Checklist
#
# ### Linguagens de progromação aceitas em notebooks
#
# ✅Python<br>
# ✅Julia<br>
# ✅R<br>
#
# ### Linguagens que iremos utilizar no curso
#
# ✅Python<br>
# ❌Julia<br>
# ❌R<br>
